# %% [markdown]
# # 상위100개 명사 워드클라우드
# --------------
# - '집'과 같은 한 자리 명사이지만 유의미한 것들이 있어 단어 길이 제한은 두지 않았음.
# - '지역명' 역시 불용어처리하지 않았음
# - 정제할때 주관이 많이 들어갈것같아 명사까지만 했음...

# %%
import pandas as pd
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import platform
from konlpy.tag import Okt
from collections import Counter
import nltk
from nltk.corpus import stopwords

# %%
Seoul=pd.read_excel('서울 200806 통합.xlsx',index_row=0)

# %%
Seoul_file=list(Seoul['파일이름'])

# %%
def wordcloudf2(list):
    okt=Okt()
    morphs=[]

    for sentence in list:
        morphs.append(okt.pos(sentence))
        
    noun_list=[]

    for i in morphs:
        for word, tag in i:
            if tag in['Noun']:
                noun_list.append(word)
                
    count=Counter(noun_list)

    words=dict(count.most_common(100))
    
    wordcloud = WordCloud(font_path = 'C:/Windows/Fonts/malgun.ttf', 
                      background_color = 'black', 
                      width=800, height=600).generate_from_frequencies(words) 

    plt.figure(figsize=(15,10))
    plt.axis('off') 
    plt.imshow(wordcloud)
    return plt.show()

# %%
wordcloudf2(Seoul_file)

# %% [markdown]
# - 집, 주택과 같은 부동산 관련 데이터의 비율이 많음 -> 카테고리 분류가 잘 되어 있는가?

# %%
강원=pd.read_excel('강원도 200806 통합.xlsx',index_row=0)
강원_file=list(강원['파일이름'])

# %%
wordcloudf2(강원_file)

# %%
경기=pd.read_excel('경기도 200806 통합.xlsx',index_row=0)
경기_file=list(경기['파일이름'])

# %%
wordcloudf2(경기_file)

# %%
경남=pd.read_excel('경상남도 200806 통합.xlsx',index_row=0)
경남_file=list(경남['파일이름'])

# %%
wordcloudf2(경남_file)

# %%
경북=pd.read_excel('경상북도 200806 통합.xlsx',index_row=0)
경북_file=list(경북['파일이름'])

# %%
wordcloudf2(경북_file)

# %%
광주=pd.read_excel('광주 200806 통합.xlsx',index_row=0)
광주_file=list(광주['파일이름'])

# %%
wordcloudf2(광주_file)

# %%
대구=pd.read_excel('대구 200806 통합.xlsx',index_row=0)
대구_file=list(대구['파일이름'])

# %%
wordcloudf2(대구_file)

# %%
대전=pd.read_excel('대전 200806 통합.xlsx',index_row=0)
대전_file=list(대전['파일이름'])

# %%
wordcloudf2(대전_file)

# %%
부산=pd.read_excel('부산 200806 통합.xlsx',index_row=0)
부산_file=list(부산['파일이름'])

# %%
wordcloudf2(부산_file)

# %%
세종=pd.read_excel('세종 200806 통합.xlsx',index_row=0)
세종_file=list(세종['파일이름'])

# %%
wordcloudf2(세종_file)

# %%
인천=pd.read_excel('인천 200806 통합.xlsx',index_row=0)
인천_file=list(인천['파일이름'])

# %%
wordcloudf2(인천_file)

# %%
전남=pd.read_excel('전라남도 200806 통합.xlsx',index_row=0)
전남_file=list(전남['파일이름'])

# %%
wordcloudf2(전남_file)

# %%
전북=pd.read_excel('전라북도 200806 통합.xlsx',index_row=0)
전북_file=list(전북['파일이름'])

# %%
wordcloudf2(전북_file)

# %%
충남=pd.read_excel('충청남도 200806 통합.xlsx',index_row=0)
충남_file=list(충남['파일이름'])

# %%
wordcloudf2(충남_file)

# %%
충북=pd.read_excel('충청북도 200806 통합.xlsx',index_row=0)
충북_file=list(충북['파일이름'])

# %%
wordcloudf2(충북_file)

# %%
제주=pd.read_excel('제주 200806 통합.xlsx',index_row=0)
제주_file=list(제주['파일이름'])

# %%
wordcloudf2(제주_file)
